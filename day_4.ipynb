# %%
from package.math import add,mul,div,sub
add(5,4)
# Out:
# 9

# %%
mul(9,4)
# Out:
# 36

# %%
div(9,4)
# Out:
# 2.25

# %%
sub(9,4)
# Out:
# 5

# %%
import day_3
inv=day_3.Invoice("in1","kailai",12.2,10.1,day_3.Status.PAID)
print(day_3.Validate(inv).validation())
# Out:
# Validation Successfull

# %%
import sys
print(sys.path)
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\python311.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0', 'c:\\Users\\Kaila\\aerele_practice\\env', '', 'c:\\Users\\Kaila\\aerele_practice\\env\\Lib\\site-packages']

# %%
from dotenv import load_dotenv
import os

load_dotenv()
name= os.getenv("NAME")
print(name)
# Out:
# kailai

# %%
import package
print(package.__version__)
# Out:
# 1.0.0

# %%
from Invoice import api
api.process()
# Out:
# Invoice Id is in1
# Customer Name is sks
# Invoice amount is 11
# Invoice completed with Tax: 1.1

# %%
class hi:
    def __str__(self):
        return "hi"
    def __repr__(self):
        return "hey"

# %%
def decorator(func):
    def wrap():
        print("hi")
        func()
        print("bye")
    return wrap
@decorator
def hi():
    print("hello")

# %%
hi()
# Out:
# hi
# hello
# bye

# %%
__name__
# Out:
# '__main__'

# %%
import day_3
day_3.__name__
# Out:
# 'day_3'

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    @property
    def age(self):
        return self.age
    @age.setter
    def age(self,value):
        self.age=value

# %%
kailai=Student("kailai",20)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
